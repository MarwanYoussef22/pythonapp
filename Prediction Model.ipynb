# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report

# Load your dataset
df = pd.read_csv('troop_movements.csv')  # Replace 'character_data.csv' with your dataset file
print(df)
# Out:
#                timestamp  unit_id           unit_type empire_or_resistance  \
# 0    2023-10-10 09:36:09        1  resistance_soldier               empire
# 1    2023-10-10 09:36:08        2               at-at               empire
# 2    2023-10-10 09:36:07        3         tie_fighter               empire
# 3    2023-10-10 09:36:06        4               at-st               empire
# 4    2023-10-10 09:36:05        5              x-wing           resistance
# ..                   ...      ...                 ...                  ...
# 995  2023-10-10 09:19:34      996              x-wing               empire
# 996  2023-10-10 09:19:33      997  resistance_soldier           resistance
# 997  2023-10-10 09:19:32      998              x-wing               empire
# 998  2023-10-10 09:19:31      999         tie_fighter           resistance
# 999  2023-10-10 09:19:30     1000        stormtrooper               empire
#
# ...

# %%
# Encode categorical variables (homeworld and unit type)
#le = LabelEncoder()
#df['homeworld_encoded'] = le.fit_transform(df['homeworld'])
#df['unit_type_encoded'] = le.fit_transform(df['unit_type'])

# Define features (X) and target (y)
X = df[['homeworld', 'unit_type']]
Y = df['empire_or_resistance']  # Target variable

print(X)
print(Y)
# Out:
#        homeworld           unit_type
# 0        Serenno  resistance_soldier
# 1        Sullust               at-at
# 2     Muunilinst         tie_fighter
# 3          Kalee               at-st
# 4        Troiken              x-wing
# ..           ...                 ...
# 995      Iktotch              x-wing
# 996         Ojom  resistance_soldier
# 997        Skako              x-wing
# 998     Champala         tie_fighter
# 999  Glee Anselm        stormtrooper
#
# [1000 rows x 2 columns]
# 0          empire
# 1          empire
# 2          empire
# 3          empire
# 4      resistance
#           ...
# 995        empire
# 996    resistance
# 997        empire
# 998    resistance
# 999        empire
# Name: empire_or_resistance, Length: 1000, dtype: object

# %%
# Encode categorical variables (homeworld and unit type)
#le = LabelEncoder()
#df['homeworld_encoded'] = le.fit_transform(df['homeworld'])
#df['unit_type_encoded'] = le.fit_transform(df['unit_type'])
X_encoded = pd.get_dummies(X)
print(X_encoded)
# Out:
#      homeworld_Alderaan  homeworld_Aleen Minor  homeworld_Bestine IV  \
# 0                     0                      0                     0
# 1                     0                      0                     0
# 2                     0                      0                     0
# 3                     0                      0                     0
# 4                     0                      0                     0
# ..                  ...                    ...                   ...
# 995                   0                      0                     0
# 996                   0                      0                     0
# 997                   0                      0                     0
# 998                   0                      0                     0
# 999                   0                      0                     0
#
#      homeworld_Cerea  homeworld_Champala  homeworld_Chandrila  \
# 0                  0                   0                    0
# ...
